# %% [markdown]
# # 🎬 Netflix Data Analysis using Python

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("../data/netflix.csv")
df.head()

# %%
df.shape

# %% [markdown]
# ## Dataset Overview

# %%
df.info()

# %%
df.isna().sum()

# %% [markdown]
# ## Data Cleaning

# %%
df['country'].fillna('Unknown', inplace=True)
df['director'].fillna('Not Available', inplace=True)
df['cast'].fillna('Not Available', inplace=True)

df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# %% [markdown]
# ## Movies vs TV Shows

# %%
sns.countplot(data=df, x='type')
plt.title("Movies vs TV Shows on Netflix")
plt.show()

# %% [markdown]
# ## Content Added Per Year

# %%
df['year_added'] = df['date_added'].dt.year

sns.countplot(y=df['year_added'])
plt.title("Content Added per Year")
plt.show()

# %% [markdown]
# ## Top 10 Content Producing Countries

# %%
df['country'].value_counts().head(10).plot(kind='barh')
plt.title("Top 10 Content Producing Countries")
plt.show()

# %% [markdown]
# ## Most Common Genres

# %%
df['listed_in'].str.split(', ').explode().value_counts().head(10).plot(kind='barh')
plt.title("Top Genres on Netflix")
plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This analysis highlights Netflix’s content growth trends, dominance of movies,
# and genre preferences. These insights help understand how Netflix expands
# its content library globally.
